# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
import pyaudio
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# *mfcc: Mel Frequency Cepstral Coefficient, represents the short-term power spectrum of a sound*
#
# *chroma: Pertains to the 12 different pitch classes*
#
# *mel: Mel Spectrogram Frequency*

# %%
def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))   #stft(short term fourier transform) calculates the magnitude of frequency
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
    return result

# %%
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}
observed_emotions=['calm', 'happy', 'fearful', 'disgust', 'angry', 'disgust']

# %%
def load_data(test_size=0.2):
    x,y=[],[]
    for file in glob.glob("speech-emotion-recognition-ravdess-data//Actor_*//*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)
def displayEmotion(emotion):
    print(emotions[emotion])

# %%
x_train,x_test,y_train,y_test=load_data(test_size=0.25)

# %%
print((x_train.shape[0], x_test.shape[0]))
# Out:
# (720, 240)

# %%
print(f'Features extracted: {x_train.shape[1]}')
# Out:
# Features extracted: 180

# %%
model=MLPClassifier(alpha=0.01, batch_size=128, epsilon=1e-08, hidden_layer_sizes=(200,), learning_rate='adaptive', max_iter=500)

# %%
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=128, hidden_layer_sizes=(200,),
#               learning_rate='adaptive', max_iter=500)

# %%
y_pred=model.predict(x_test)

# %%
accuracy=accuracy_score(y_true=y_test, y_pred=y_pred)
print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 70.83%

# %%
for i in range(240):
    print('{}) Prediction = {}\n   True= {}'.format(i,y_pred[i],y_test[i]))
# Out:
# 0) Prediction = calm
#    True= angry
# 1) Prediction = happy
#    True= happy
# 2) Prediction = fearful
#    True= fearful
# 3) Prediction = disgust
#    True= calm
# 4) Prediction = happy
#    True= angry
# 5) Prediction = fearful
#    True= fearful
# 6) Prediction = fearful
#    True= calm
# 7) Prediction = disgust
#    True= disgust
# 8) Prediction = calm
#    True= calm
# 9) Prediction = fearful
#    True= fearful
# 10) Prediction = fearful
#    True= fearful
# 11) Prediction = calm
#    True= calm
# 12) Prediction = happy
#    True= disgust
# 13) Prediction = disgust
#    True= disgust
# 14) Prediction = fearful
#    True= angry
# 15) Prediction = disgust
#    True= calm
# 16) Prediction = disgust
#    True= disgust
# 17) Prediction = calm
#    True= calm
# 18) Prediction = calm
#    True= calm
# 19) Prediction = happy
#    True= happy
# 20) Prediction = fearful
#    True= disgust
# 21) Prediction = happy
#    True= happy
# 22) Prediction = calm
#    True= calm
# 23) Prediction = calm
#    True= calm
# 24) Prediction = angry
#    True= disgust
# 25) Prediction = calm
#    True= calm
# 26) Prediction = fearful
#    True= fearful
# 27) Prediction = disgust
#    True= disgust
# 28) Prediction = fearful
#    True= disgust
# 29) Prediction = calm
#    True= happy
# 30) Prediction = fearful
#    True= fearful
# 31) Prediction = fearful
#    True= fearful
# 32) Prediction = calm
#    True= calm
# 33) Prediction = disgust
#    True= disgust
# 34) Prediction = disgust
#    True= disgust
# 35) Prediction = angry
#    True= angry
# 36) Prediction = angry
#    True= angry
# 37) Prediction = happy
#    True= disgust
# 38) Prediction = happy
#    True= disgust
# 39) Prediction = calm
#    True= calm
# 40) Prediction = fearful
#    True= fearful
# 41) Prediction = calm
#    True= calm
# 42) Prediction = calm
#    True= calm
# 43) Prediction = angry
#    True= disgust
# 44) Prediction = disgust
#    True= disgust
# 45) Prediction = happy
#    True= happy
# 46) Prediction = calm
#    True= calm
# 47) Prediction = angry
#    True= angry
# 48) Prediction = calm
#    True= calm
# 49) Prediction = fearful
#    True= disgust
# 50) Prediction = fearful
#    True= happy
# 51) Prediction = angry
#    True= angry
# 52) Prediction = fearful
#    True= angry
# 53) Prediction = happy
#    True= happy
# 54) Prediction = fearful
#    True= fearful
# 55) Prediction = angry
#    True= disgust
# 56) Prediction = angry
#    True= disgust
# 57) Prediction = calm
#    True= calm
# 58) Prediction = fearful
#    True= disgust
# 59) Prediction = happy
#    True= disgust
# 60) Prediction = happy
#    True= happy
# 61) Prediction = happy
#    True= happy
# 62) Prediction = angry
#    True= angry
# 63) Prediction = calm
#    True= calm
# 64) Prediction = angry
#    True= disgust
# 65) Prediction = calm
#    True= calm
# 66) Prediction = fearful
#    True= fearful
# 67) Prediction = happy
#    True= happy
# 68) Prediction = fearful
#    True= fearful
# 69) Prediction = happy
#    True= happy
# 70) Prediction = disgust
#    True= disgust
# 71) Prediction = disgust
#    True= calm
# 72) Prediction = calm
#    True= calm
# 73) Prediction = angry
#    True= angry
# 74) Prediction = fearful
#    True= disgust
# 75) Prediction = calm
#    True= calm
# 76) Prediction = angry
#    True= angry
# 77) Prediction = calm
#    True= calm
# 78) Prediction = fearful
#    True= fearful
# 79) Prediction = angry
#    True= angry
# 80) Prediction = disgust
#    True= angry
# 81) Prediction = happy
#    True= disgust
# 82) Prediction = calm
#    True= calm
# 83) Prediction = fearful
#    True= fearful
# 84) Prediction = angry
#    True= angry
# 85) Prediction = happy
#    True= happy
# 86) Prediction = disgust
#    True= angry
# 87) Prediction = calm
#    True= calm
# 88) Prediction = angry
#    True= angry
# 89) Prediction = disgust
#    True= disgust
# 90) Prediction = calm
#    True= calm
# 91) Prediction = angry
#    True= angry
# 92) Prediction = calm
#    True= calm
# 93) Prediction = angry
#    True= happy
# 94) Prediction = disgust
#    True= disgust
# 95) Prediction = fearful
#    True= fearful
# 96) Prediction = angry
#    True= angry
# 97) Prediction = fearful
#    True= fearful
# 98) Prediction = fearful
#    True= fearful
# 99) Prediction = angry
#    True= angry
# 100) Prediction = fearful
#    True= disgust
# 101) Prediction = fearful
#    True= happy
# 102) Prediction = disgust
#    True= disgust
# 103) Prediction = fearful
#    True= fearful
# 104) Prediction = angry
#    True= angry
# 105) Prediction = disgust
#    True= disgust
# 106) Prediction = fearful
#    True= happy
# 107) Prediction = disgust
#    True= fearful
# 108) Prediction = angry
#    True= angry
# 109) Prediction = disgust
#    True= disgust
# 110) Prediction = disgust
#    True= disgust
# 111) Prediction = fearful
#    True= fearful
# 112) Prediction = angry
#    True= happy
# 113) Prediction = fearful
#    True= fearful
# 114) Prediction = disgust
#    True= fearful
# 115) Prediction = happy
#    True= fearful
# 116) Prediction = calm
#    True= disgust
# 117) Prediction = fearful
#    True= fearful
# 118) Prediction = angry
#    True= angry
# 119) Prediction = angry
#    True= angry
# 120) Prediction = angry
#    True= calm
# 121) Prediction = angry
#    True= angry
# 122) Prediction = disgust
#    True= angry
# 123) Prediction = fearful
#    True= fearful
# 124) Prediction = fearful
#    True= fearful
# 125) Prediction = angry
#    True= angry
# 126) Prediction = fearful
#    True= fearful
# 127) Prediction = angry
#    True= angry
# 128) Prediction = angry
#    True= disgust
# 129) Prediction = disgust
#    True= fearful
# 130) Prediction = fearful
#    True= fearful
# 131) Prediction = calm
#    True= calm
# 132) Prediction = calm
#    True= calm
# 133) Prediction = fearful
#    True= fearful
# 134) Prediction = calm
#    True= calm
# 135) Prediction = happy
#    True= fearful
# 136) Prediction = calm
#    True= calm
# 137) Prediction = fearful
#    True= fearful
# 138) Prediction = disgust
#    True= disgust
# 139) Prediction = happy
#    True= happy
# 140) Prediction = angry
#    True= angry
# 141) Prediction = angry
#    True= fearful
# 142) Prediction = angry
#    True= angry
# 143) Prediction = happy
#    True= happy
# 144) Prediction = angry
#    True= disgust
# 145) Prediction = disgust
#    True= disgust
# 146) Prediction = disgust
#    True= disgust
# 147) Prediction = disgust
#    True= disgust
# 148) Prediction = disgust
#    True= calm
# 149) Prediction = fearful
#    True= fearful
# 150) Prediction = calm
#    True= calm
# 151) Prediction = happy
#    True= happy
# 152) Prediction = calm
#    True= calm
# 153) Prediction = fearful
#    True= fearful
# 154) Prediction = fearful
#    True= fearful
# 155) Prediction = disgust
#    True= happy
# 156) Prediction = fearful
#    True= fearful
# 157) Prediction = happy
#    True= happy
# 158) Prediction = angry
#    True= angry
# 159) Prediction = fearful
#    True= disgust
# 160) Prediction = angry
#    True= angry
# 161) Prediction = disgust
#    True= disgust
# 162) Prediction = calm
#    True= calm
# 163) Prediction = angry
#    True= angry
# 164) Prediction = fearful
#    True= calm
# 165) Prediction = calm
#    True= disgust
# 166) Prediction = calm
#    True= calm
# 167) Prediction = calm
#    True= calm
# 168) Prediction = fearful
#    True= fearful
# 169) Prediction = angry
#    True= angry
# 170) Prediction = disgust
#    True= calm
# 171) Prediction = fearful
#    True= fearful
# 172) Prediction = fearful
#    True= fearful
# 173) Prediction = fearful
#    True= fearful
# 174) Prediction = fearful
#    True= calm
# 175) Prediction = fearful
#    True= fearful
# 176) Prediction = happy
#    True= happy
# 177) Prediction = calm
#    True= calm
# 178) Prediction = angry
#    True= angry
# 179) Prediction = fearful
#    True= fearful
# 180) Prediction = angry
#    True= angry
# 181) Prediction = disgust
#    True= disgust
# 182) Prediction = calm
#    True= calm
# 183) Prediction = fearful
#    True= happy
# 184) Prediction = angry
#    True= happy
# 185) Prediction = calm
#    True= calm
# 186) Prediction = calm
#    True= angry
# 187) Prediction = happy
#    True= happy
# 188) Prediction = happy
#    True= happy
# 189) Prediction = calm
#    True= calm
# 190) Prediction = angry
#    True= angry
# 191) Prediction = happy
#    True= happy
# 192) Prediction = angry
#    True= happy
# 193) Prediction = happy
#    True= disgust
# 194) Prediction = fearful
#    True= happy
# 195) Prediction = fearful
#    True= fearful
# 196) Prediction = calm
#    True= disgust
# 197) Prediction = calm
#    True= calm
# 198) Prediction = fearful
#    True= fearful
# 199) Prediction = happy
#    True= happy
# 200) Prediction = disgust
#    True= disgust
# 201) Prediction = calm
#    True= calm
# 202) Prediction = happy
#    True= happy
# 203) Prediction = fearful
#    True= fearful
# 204) Prediction = happy
#    True= disgust
# 205) Prediction = disgust
#    True= disgust
# 206) Prediction = happy
#    True= disgust
# 207) Prediction = disgust
#    True= disgust
# 208) Prediction = fearful
#    True= happy
# 209) Prediction = fearful
#    True= fearful
# 210) Prediction = happy
#    True= happy
# 211) Prediction = calm
#    True= calm
# 212) Prediction = happy
#    True= happy
# 213) Prediction = happy
#    True= happy
# 214) Prediction = calm
#    True= calm
# 215) Prediction = calm
#    True= calm
# 216) Prediction = fearful
#    True= fearful
# 217) Prediction = calm
#    True= calm
# 218) Prediction = angry
#    True= happy
# 219) Prediction = angry
#    True= disgust
# 220) Prediction = calm
#    True= happy
# 221) Prediction = disgust
#    True= disgust
# 222) Prediction = disgust
#    True= disgust
# 223) Prediction = calm
#    True= calm
# 224) Prediction = happy
#    True= fearful
# 225) Prediction = disgust
#    True= disgust
# 226) Prediction = disgust
#    True= disgust
# 227) Prediction = calm
#    True= calm
# 228) Prediction = happy
#    True= disgust
# 229) Prediction = angry
#    True= calm
# 230) Prediction = happy
#    True= happy
# 231) Prediction = fearful
#    True= disgust
# 232) Prediction = angry
#    True= angry
# 233) Prediction = fearful
#    True= disgust
# 234) Prediction = calm
#    True= disgust
# 235) Prediction = happy
#    True= fearful
# 236) Prediction = calm
#    True= calm
# 237) Prediction = angry
#    True= angry
# 238) Prediction = angry
#    True= angry
# 239) Prediction = happy
#    True= happy

# %%
def emotionRecognition(audioFile, mfcc=False, chroma=False, mel=False):
    emotion=audioFile.split("-")[2]
    with open(audioFile) as audioFile:
        if chroma:
            stft=np.abs(librosa.stft(X))
            result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
        if mel:
            mel=np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
            result=np.hstack((result, mel))
    displayEmotion(emotion)

# %%
audioFile = "sample.wav"
emotionRecognition(audioFile)
# Out:
# disgust
